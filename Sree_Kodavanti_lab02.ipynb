# %%
import numpy as np

np.random.seed(4) # To make repeatable
LEARNING_RATE = 0.1
index_list = [0, 1, 2, 3] # Used to randomize order

# Define training examples.
x_train = [np.array([1.0, 0.0, 0.0]),
           np.array([1.0, 0.0, 1.0]),
           np.array([1.0, 1.0, 0.0]),
           np.array([1.0, 1.0, 1.0])]
# Output (ground truth)
y_train = [0.0, 1.0, 1.0, 0.0]

# %% [markdown]
# ##### declare variables to hold the state of our three neurons

# %%
def neuron_w(input_count):
    weights = np.zeros(input_count+1)
    for i in range(1, (input_count+1)):
        weights[i] = np.random.uniform(-1.0, 1.0)
    return weights

n_w = [neuron_w(2), neuron_w(2), neuron_w(2), neuron_w(3)]
n_y = [0, 0, 0, 0]
n_error = [0, 0, 0, 0]

# %% [markdown]
# ##### (for my reference):The next code snippet starts with a function to print all the nine weights of the network (each print statement prints a three-element weight vector). The forward_pass function first computes the outputs of neurons 0 and 1 with the same inputs (the inputs from the training example) and then puts their outputs into an array, together with a bias value of 1.0, to use as input to neuron 2. That is, this function defines the topology of the network. We use tanh for the neurons in the first layer and the logistic sigmoid function for the output neuron.
#
# ##### The backward_pass function starts by computing the derivative of the error function and then computes the derivative of the activation function for the output neuron. The error term of the output neuron is computed by multiplying these two together. We then continue to backpropagate the error to each of the two neurons in the hidden layer. This is done by computing the derivatives of their activation functions and multiplying these derivatives by the error term from the output neuron and by the weight to the output neuron.

# %%
def show_learning():
    print('Current weights:')
    for i, w in enumerate(n_w):
        print('neuron ', i, ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    print('----------------')

def forward_pass(x):
    global n_y
    # Neuron 0
    n_y[0] = np.tanh(np.dot(n_w[0], x))
     # Neuron 1
    n_y[1] = np.tanh(np.dot(n_w[1], x))
    # Neuron 2
    n_y[2] = np.tanh(np.dot(n_w[2], x))
    # the 1.0 is bias
    n3_inputs = np.array([1.0, n_y[0], n_y[1], n_y[2]])
    n_y[3] = 1.0 / (1.0 + np.exp(-np.dot(n_w[3], n3_inputs)))

def backward_pass(y_truth):
    global n_error
    error_prime = -(y_truth - n_y[3]) # Derivative of loss-func
    derivative = n_y[3] * (1.0 - n_y[3]) # Logistic derivative
    n_error[3] = error_prime * derivative
    derivative = 1.0 - n_y[0]**2 # tanh derivative
    n_error[0] = n_w[3][1] * n_error[3] * derivative
    derivative = 1.0 - n_y[1]**2 # tanh derivative
    n_error[1] = n_w[3][2] * n_error[3] * derivative
    derivative = 1.0 - n_y[2]**2 # tanh derivative
    n_error[2] = n_w[3][3] * n_error[3] * derivative

def adjust_weights(x):
    global n_w
    n_w[0] -= (x * LEARNING_RATE * n_error[0])
    n_w[1] -= (x * LEARNING_RATE * n_error[1])
    n_w[2] -= (x * LEARNING_RATE * n_error[2])
    n3_inputs = np.array([1.0, n_y[0], n_y[1], n_y[2]]) # 1.0 is bias
    n_w[3] -= (n3_inputs * LEARNING_RATE * n_error[3])

# Network training loop.
all_correct = False
while not all_correct: # Train until converged
    all_correct = True
    np.random.shuffle(index_list) # Randomize order
    for i in index_list: # Train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() # Show updated weights
    for i in range(len(x_train)): # Check if converged
        forward_pass(x_train[i])
        print('x1 =', '%4.1f' % x_train[i][1], ', x2 =',
              '%4.1f' % x_train[i][2], ', y =',
              '%.4f' % n_y[3])
        if(((y_train[i] < 0.5) and (n_y[3] >= 0.5))
                or ((y_train[i] >= 0.5) and (n_y[3] < 0.5))):
            all_correct = False
# Out:
# Streaming output truncated to the last 5000 lines.
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.38 , w2 = -1.31
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1477
# x1 =  0.0 , x2 =  1.0 , y = 0.8134
# x1 =  1.0 , x2 =  0.0 , y = 0.5193
# x1 =  1.0 , x2 =  1.0 , y = 0.5412
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.38 , w2 = -1.31
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1477
# x1 =  0.0 , x2 =  1.0 , y = 0.8139
# x1 =  1.0 , x2 =  0.0 , y = 0.5197
# x1 =  1.0 , x2 =  1.0 , y = 0.5415
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.04
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.39 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1476
# x1 =  0.0 , x2 =  1.0 , y = 0.8140
# x1 =  1.0 , x2 =  0.0 , y = 0.5198
# x1 =  1.0 , x2 =  1.0 , y = 0.5414
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.38 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.50 , w2 =  1.94
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.38 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1475
# x1 =  0.0 , x2 =  1.0 , y = 0.8143
# x1 =  1.0 , x2 =  0.0 , y = 0.5200
# x1 =  1.0 , x2 =  1.0 , y = 0.5415
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.40 , w1 =  2.40 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1473
# x1 =  0.0 , x2 =  1.0 , y = 0.8143
# x1 =  1.0 , x2 =  0.0 , y = 0.5197
# x1 =  1.0 , x2 =  1.0 , y = 0.5411
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.50 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.37 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1472
# x1 =  0.0 , x2 =  1.0 , y = 0.8146
# x1 =  1.0 , x2 =  0.0 , y = 0.5200
# x1 =  1.0 , x2 =  1.0 , y = 0.5412
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.40 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.40 , w1 =  2.40 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1469
# x1 =  0.0 , x2 =  1.0 , y = 0.8144
# x1 =  1.0 , x2 =  0.0 , y = 0.5195
# x1 =  1.0 , x2 =  1.0 , y = 0.5405
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.38 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 =  0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1469
# x1 =  0.0 , x2 =  1.0 , y = 0.8147
# x1 =  1.0 , x2 =  0.0 , y = 0.5198
# x1 =  1.0 , x2 =  1.0 , y = 0.5407
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.40 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.39 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1466
# x1 =  0.0 , x2 =  1.0 , y = 0.8147
# x1 =  1.0 , x2 =  0.0 , y = 0.5195
# x1 =  1.0 , x2 =  1.0 , y = 0.5402
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.44 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.40 , w1 =  2.41 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.12 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.41 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1463
# x1 =  0.0 , x2 =  1.0 , y = 0.8146
# x1 =  1.0 , x2 =  0.0 , y = 0.5191
# x1 =  1.0 , x2 =  1.0 , y = 0.5396
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.38 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.95
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1463
# x1 =  0.0 , x2 =  1.0 , y = 0.8150
# x1 =  1.0 , x2 =  0.0 , y = 0.5194
# x1 =  1.0 , x2 =  1.0 , y = 0.5398
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.51 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.21 , w2 =  0.05
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.41 , w2 = -1.31
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1461
# x1 =  0.0 , x2 =  1.0 , y = 0.8149
# x1 =  1.0 , x2 =  0.0 , y = 0.5190
# x1 =  1.0 , x2 =  1.0 , y = 0.5393
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1460
# x1 =  0.0 , x2 =  1.0 , y = 0.8152
# x1 =  1.0 , x2 =  0.0 , y = 0.5193
# x1 =  1.0 , x2 =  1.0 , y = 0.5394
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1459
# x1 =  0.0 , x2 =  1.0 , y = 0.8155
# x1 =  1.0 , x2 =  0.0 , y = 0.5196
# x1 =  1.0 , x2 =  1.0 , y = 0.5396
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.00 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.40 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1460
# x1 =  0.0 , x2 =  1.0 , y = 0.8160
# x1 =  1.0 , x2 =  0.0 , y = 0.5200
# x1 =  1.0 , x2 =  1.0 , y = 0.5398
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1460
# x1 =  0.0 , x2 =  1.0 , y = 0.8165
# x1 =  1.0 , x2 =  0.0 , y = 0.5204
# x1 =  1.0 , x2 =  1.0 , y = 0.5401
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.39 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.40 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.52 , w2 =  1.96
# neuron  1 : w0 = -0.01 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.43 , w1 =  2.40 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1460
# x1 =  0.0 , x2 =  1.0 , y = 0.8169
# x1 =  1.0 , x2 =  0.0 , y = 0.5207
# x1 =  1.0 , x2 =  1.0 , y = 0.5403
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.21 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.42 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.21 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.42 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1457
# x1 =  0.0 , x2 =  1.0 , y = 0.8166
# x1 =  1.0 , x2 =  0.0 , y = 0.5202
# x1 =  1.0 , x2 =  1.0 , y = 0.5395
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.21 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.42 , w2 = -1.32
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1454
# x1 =  0.0 , x2 =  1.0 , y = 0.8165
# x1 =  1.0 , x2 =  0.0 , y = 0.5198
# x1 =  1.0 , x2 =  1.0 , y = 0.5390
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.40 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.96
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.13 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.33
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1453
# x1 =  0.0 , x2 =  1.0 , y = 0.8167
# x1 =  1.0 , x2 =  0.0 , y = 0.5200
# x1 =  1.0 , x2 =  1.0 , y = 0.5389
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.40 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.41 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1452
# x1 =  0.0 , x2 =  1.0 , y = 0.8168
# x1 =  1.0 , x2 =  0.0 , y = 0.5201
# x1 =  1.0 , x2 =  1.0 , y = 0.5389
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.06
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.40 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.40 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1451
# x1 =  0.0 , x2 =  1.0 , y = 0.8170
# x1 =  1.0 , x2 =  0.0 , y = 0.5203
# x1 =  1.0 , x2 =  1.0 , y = 0.5389
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.53 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.21
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.13 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.43 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1449
# x1 =  0.0 , x2 =  1.0 , y = 0.8169
# x1 =  1.0 , x2 =  0.0 , y = 0.5199
# x1 =  1.0 , x2 =  1.0 , y = 0.5383
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.43 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.21
# neuron  3 : w0 = -0.41 , w1 =  2.43 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.45 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1446
# x1 =  0.0 , x2 =  1.0 , y = 0.8167
# x1 =  1.0 , x2 =  0.0 , y = 0.5195
# x1 =  1.0 , x2 =  1.0 , y = 0.5377
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.43 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1445
# x1 =  0.0 , x2 =  1.0 , y = 0.8168
# x1 =  1.0 , x2 =  0.0 , y = 0.5193
# x1 =  1.0 , x2 =  1.0 , y = 0.5373
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.41 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1445
# x1 =  0.0 , x2 =  1.0 , y = 0.8171
# x1 =  1.0 , x2 =  0.0 , y = 0.5196
# x1 =  1.0 , x2 =  1.0 , y = 0.5375
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.43 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.44 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1443
# x1 =  0.0 , x2 =  1.0 , y = 0.8171
# x1 =  1.0 , x2 =  0.0 , y = 0.5193
# x1 =  1.0 , x2 =  1.0 , y = 0.5370
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.41 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.41 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.42 , w2 = -1.34
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1443
# x1 =  0.0 , x2 =  1.0 , y = 0.8174
# x1 =  1.0 , x2 =  0.0 , y = 0.5197
# x1 =  1.0 , x2 =  1.0 , y = 0.5373
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.54 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.43 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.97
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.07
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.44 , w2 = -1.33
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.97
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1441
# x1 =  0.0 , x2 =  1.0 , y = 0.8174
# x1 =  1.0 , x2 =  0.0 , y = 0.5194
# x1 =  1.0 , x2 =  1.0 , y = 0.5367
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.41 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.97
# neuron  1 : w0 = -0.02 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.41 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.42 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1443
# x1 =  0.0 , x2 =  1.0 , y = 0.8179
# x1 =  1.0 , x2 =  0.0 , y = 0.5199
# x1 =  1.0 , x2 =  1.0 , y = 0.5370
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.44 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1441
# x1 =  0.0 , x2 =  1.0 , y = 0.8178
# x1 =  1.0 , x2 =  0.0 , y = 0.5195
# x1 =  1.0 , x2 =  1.0 , y = 0.5365
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.44 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.41 , w1 =  2.44 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1438
# x1 =  0.0 , x2 =  1.0 , y = 0.8176
# x1 =  1.0 , x2 =  0.0 , y = 0.5191
# x1 =  1.0 , x2 =  1.0 , y = 0.5359
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.44 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1436
# x1 =  0.0 , x2 =  1.0 , y = 0.8177
# x1 =  1.0 , x2 =  0.0 , y = 0.5190
# x1 =  1.0 , x2 =  1.0 , y = 0.5356
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.44 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.14 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.43 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1435
# x1 =  0.0 , x2 =  1.0 , y = 0.8176
# x1 =  1.0 , x2 =  0.0 , y = 0.5187
# x1 =  1.0 , x2 =  1.0 , y = 0.5351
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.42 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.42 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.55 , w2 =  1.98
# neuron  1 : w0 = -0.03 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.42 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1436
# x1 =  0.0 , x2 =  1.0 , y = 0.8181
# x1 =  1.0 , x2 =  0.0 , y = 0.5192
# x1 =  1.0 , x2 =  1.0 , y = 0.5354
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.08
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.42 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.35
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1435
# x1 =  0.0 , x2 =  1.0 , y = 0.8184
# x1 =  1.0 , x2 =  0.0 , y = 0.5195
# x1 =  1.0 , x2 =  1.0 , y = 0.5355
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.34
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1434
# x1 =  0.0 , x2 =  1.0 , y = 0.8185
# x1 =  1.0 , x2 =  0.0 , y = 0.5194
# x1 =  1.0 , x2 =  1.0 , y = 0.5352
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.05 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.98
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1432
# x1 =  0.0 , x2 =  1.0 , y = 0.8183
# x1 =  1.0 , x2 =  0.0 , y = 0.5190
# x1 =  1.0 , x2 =  1.0 , y = 0.5347
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.45 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1431
# x1 =  0.0 , x2 =  1.0 , y = 0.8185
# x1 =  1.0 , x2 =  0.0 , y = 0.5190
# x1 =  1.0 , x2 =  1.0 , y = 0.5344
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.56 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.46 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.46 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1429
# x1 =  0.0 , x2 =  1.0 , y = 0.8184
# x1 =  1.0 , x2 =  0.0 , y = 0.5187
# x1 =  1.0 , x2 =  1.0 , y = 0.5340
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.46 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.44 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1428
# x1 =  0.0 , x2 =  1.0 , y = 0.8185
# x1 =  1.0 , x2 =  0.0 , y = 0.5185
# x1 =  1.0 , x2 =  1.0 , y = 0.5336
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.45 , w1 =  2.43 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.43 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.43 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1430
# x1 =  0.0 , x2 =  1.0 , y = 0.8191
# x1 =  1.0 , x2 =  0.0 , y = 0.5191
# x1 =  1.0 , x2 =  1.0 , y = 0.5340
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.04 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.16 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.44 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1430
# x1 =  0.0 , x2 =  1.0 , y = 0.8193
# x1 =  1.0 , x2 =  0.0 , y = 0.5194
# x1 =  1.0 , x2 =  1.0 , y = 0.5341
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.06 , w1 =  1.21 , w2 =  0.09
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.46 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.36
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1428
# x1 =  0.0 , x2 =  1.0 , y = 0.8193
# x1 =  1.0 , x2 =  0.0 , y = 0.5192
# x1 =  1.0 , x2 =  1.0 , y = 0.5337
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.45 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.21 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.46 , w2 = -1.35
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.48 , w1 =  1.16 , w2 = -0.20
# neuron  3 : w0 = -0.44 , w1 =  2.45 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.05 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.16 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.37
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1428
# x1 =  0.0 , x2 =  1.0 , y = 0.8194
# x1 =  1.0 , x2 =  0.0 , y = 0.5191
# x1 =  1.0 , x2 =  1.0 , y = 0.5334
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.57 , w2 =  1.99
# neuron  1 : w0 = -0.06 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.16 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.37
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.58 , w2 =  1.99
# neuron  1 : w0 = -0.06 , w1 =  1.21 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.15 , w2 = -0.20
# neuron  3 : w0 = -0.42 , w1 =  2.46 , w2 = -1.36
# ----------------
# Current weights:
# neuron  0 : w0 = -0.47 , w1 =  2.58 , w2 =  1.99
# neuron  1 : w0 = -0.06 , w1 =  1.22 , w2 =  0.10
# neuron  2 : w0 =  0.47 , w1 =  1.16 , w2 = -0.20
# neuron  3 : w0 = -0.43 , w1 =  2.45 , w2 = -1.37
# ----------------
# Current weights:
# ...
# x1 =  1.0 , x2 =  0.0 , y = 0.5611
# x1 =  1.0 , x2 =  1.0 , y = 0.5073
# Current weights:
# neuron  0 : w0 = -0.57 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.38 , w1 =  1.03 , w2 =  0.38
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.50 , w1 =  2.63 , w2 = -1.56
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.03 , w2 =  0.38
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.51 , w1 =  2.63 , w2 = -1.56
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.57
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1501
# x1 =  0.0 , x2 =  1.0 , y = 0.8299
# x1 =  1.0 , x2 =  0.0 , y = 0.5619
# x1 =  1.0 , x2 =  1.0 , y = 0.5065
# Current weights:
# neuron  0 : w0 = -0.57 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.38
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.51 , w1 =  2.62 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.57 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.05 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.36 , w1 =  1.05 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.57
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1505
# x1 =  0.0 , x2 =  1.0 , y = 0.8301
# x1 =  1.0 , x2 =  0.0 , y = 0.5634
# x1 =  1.0 , x2 =  1.0 , y = 0.5064
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.38 , w1 =  1.03 , w2 =  0.39
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.57
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1510
# x1 =  0.0 , x2 =  1.0 , y = 0.8305
# x1 =  1.0 , x2 =  0.0 , y = 0.5653
# x1 =  1.0 , x2 =  1.0 , y = 0.5067
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.37 , w1 =  1.04 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.61 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.03 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.58
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1515
# x1 =  0.0 , x2 =  1.0 , y = 0.8310
# x1 =  1.0 , x2 =  0.0 , y = 0.5671
# x1 =  1.0 , x2 =  1.0 , y = 0.5068
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.38 , w1 =  1.03 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.76 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.03 , w2 =  0.39
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.63 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.40 , w1 =  1.02 , w2 =  0.39
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.51 , w1 =  2.64 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.03 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.58
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1517
# x1 =  0.0 , x2 =  1.0 , y = 0.8305
# x1 =  1.0 , x2 =  0.0 , y = 0.5677
# x1 =  1.0 , x2 =  1.0 , y = 0.5057
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.03 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.40 , w1 =  1.01 , w2 =  0.40
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.51 , w1 =  2.63 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.02 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.62 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.02 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.62 , w2 = -1.58
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1519
# x1 =  0.0 , x2 =  1.0 , y = 0.8303
# x1 =  1.0 , x2 =  0.0 , y = 0.5685
# x1 =  1.0 , x2 =  1.0 , y = 0.5049
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.39 , w1 =  1.02 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.12
# neuron  1 : w0 = -0.40 , w1 =  1.01 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.64 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.40
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.51 , w1 =  2.64 , w2 = -1.57
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.40 , w1 =  1.02 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.62 , w2 = -1.58
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1519
# x1 =  0.0 , x2 =  1.0 , y = 0.8297
# x1 =  1.0 , x2 =  0.0 , y = 0.5691
# x1 =  1.0 , x2 =  1.0 , y = 0.5037
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.39 , w1 =  1.02 , w2 =  0.41
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.39 , w1 =  1.03 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.54 , w1 =  2.61 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.40 , w1 =  1.02 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.62 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.40 , w1 =  1.02 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1524
# x1 =  0.0 , x2 =  1.0 , y = 0.8300
# x1 =  1.0 , x2 =  0.0 , y = 0.5711
# x1 =  1.0 , x2 =  1.0 , y = 0.5038
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.39 , w1 =  1.02 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.18
# neuron  3 : w0 = -0.54 , w1 =  2.61 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.62 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.40 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.18
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1528
# x1 =  0.0 , x2 =  1.0 , y = 0.8302
# x1 =  1.0 , x2 =  0.0 , y = 0.5729
# x1 =  1.0 , x2 =  1.0 , y = 0.5038
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.00 , w2 =  0.42
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.64 , w2 = -1.58
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1529
# x1 =  0.0 , x2 =  1.0 , y = 0.8296
# x1 =  1.0 , x2 =  0.0 , y = 0.5735
# x1 =  1.0 , x2 =  1.0 , y = 0.5026
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.42
# neuron  2 : w0 =  0.47 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.43 , w1 =  1.00 , w2 =  0.42
# neuron  2 : w0 =  0.47 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.64 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.58 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1529
# x1 =  0.0 , x2 =  1.0 , y = 0.8290
# x1 =  1.0 , x2 =  0.0 , y = 0.5741
# x1 =  1.0 , x2 =  1.0 , y = 0.5013
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.43 , w1 =  0.99 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.25 , w2 = -0.19
# neuron  3 : w0 = -0.52 , w1 =  2.64 , w2 = -1.59
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.00 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1531
# x1 =  0.0 , x2 =  1.0 , y = 0.8286
# x1 =  1.0 , x2 =  0.0 , y = 0.5749
# x1 =  1.0 , x2 =  1.0 , y = 0.5002
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.00 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.54 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.00 , w2 =  0.43
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.77 , w2 =  2.13
# neuron  1 : w0 = -0.41 , w1 =  1.01 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.55 , w1 =  2.62 , w2 = -1.61
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.43 , w1 =  1.00 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.54 , w1 =  2.63 , w2 = -1.60
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1536
# x1 =  0.0 , x2 =  1.0 , y = 0.8287
# x1 =  1.0 , x2 =  0.0 , y = 0.5769
# x1 =  1.0 , x2 =  1.0 , y = 0.5001
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.00 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.54 , w1 =  2.63 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.45
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.55 , w1 =  2.62 , w2 = -1.61
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.42 , w1 =  1.01 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.55 , w1 =  2.62 , w2 = -1.61
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.43 , w1 =  0.99 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.54 , w1 =  2.63 , w2 = -1.61
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1541
# x1 =  0.0 , x2 =  1.0 , y = 0.8292
# x1 =  1.0 , x2 =  0.0 , y = 0.5792
# x1 =  1.0 , x2 =  1.0 , y = 0.5003
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.44 , w1 =  0.98 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.64 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.44 , w1 =  0.98 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.64 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.45 , w1 =  0.98 , w2 =  0.44
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.53 , w1 =  2.64 , w2 = -1.60
# ----------------
# Current weights:
# neuron  0 : w0 = -0.59 , w1 =  2.78 , w2 =  2.13
# neuron  1 : w0 = -0.44 , w1 =  0.99 , w2 =  0.45
# neuron  2 : w0 =  0.48 , w1 =  1.26 , w2 = -0.19
# neuron  3 : w0 = -0.54 , w1 =  2.63 , w2 = -1.61
# ----------------
# x1 =  0.0 , x2 =  0.0 , y = 0.1541
# x1 =  0.0 , x2 =  1.0 , y = 0.8285
# x1 =  1.0 , x2 =  0.0 , y = 0.5798
# x1 =  1.0 , x2 =  1.0 , y = 0.4989
